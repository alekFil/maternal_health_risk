# %%
import sys

sys.path.append("../../src")

# %%
import time

import joblib
import pandas as pd

# from analysis import (
# plot_confusion_matrix,
# plot_prc_auc_curve,
# plot_roc_auc_curve,
# )
from fitpredictgo import FitPredictGo, Results

# %%
from catboost import CatBoostClassifier

# %% [markdown]
# ## Загрузка данных

# %%
X_train = pd.read_csv("../../data/baseline/X_train.csv")
X_test = pd.read_csv("../../data/baseline/X_test.csv")
y_train = pd.read_csv("../../data/baseline/y_train.csv")
y_test = pd.read_csv("../../data/baseline/y_test.csv")

# %% [markdown]
# ## Описание исследования

# %% [markdown]
# В данном исследовании (эксперименте) предлагается применить алгоритм градиентного бустинга, реализованный в библиотеке CatBoost.
#
# Планируется осуществить обучение с подбором гиперпараметров.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Определим признаки для обучения и целевой признак

# %%
original_cat_features = []

original_num_features = [
    "age",
    "systolic_bp",
    "diastolic_bp",
    "glucose_level",
    "body_temperature",
    "heart_rate",
]

new_cat_features = ["age_group", "pressure_group"]

new_num_features = []

target = "risk_level"

cat_features = original_cat_features + new_cat_features
num_features = original_num_features + new_num_features

# %% [markdown]
# Установим дополнительную константу для указания количества блоков для кросс-валидации.

# %%
cv_folds = 5

# %%
scoring = "f1_weighted"

# %%
RANDOM_STATE = 1206

# %% [markdown]
# Определим перечень моделей для обучения. В словарь в будущем внесем результаты обучения моделей.

# %%
names = {
    "CatBoostClassifier()": None,
}

# %%
preprocessors = {
    "CatBoostClassifier()": [None],
}

# %% [markdown]
# Определим инициализационные модели для кросс-валидации

# %%
models = {
    "CatBoostClassifier()": CatBoostClassifier(
        verbose=25,
        n_estimators=100,
        cat_features=cat_features,
        random_seed=RANDOM_STATE,
    ),
}

# %% [markdown]
# Определим сетку подбора гиперпараметров

# %%
param_grid_cat = [
    {
        "catboostclassifier__auto_class_weights": ["Balanced", "SqrtBalanced"],
        "catboostclassifier__n_estimators": [50, 100],
        "catboostclassifier__learning_rate": [0.1, 0.25, 0.15, 0.17, 0.5, 1],
        "catboostclassifier__depth": range(4, 9),
        "catboostclassifier__l2_leaf_reg": [0.1, 0.5, 1, 2, 3],
    }
]

# %%
param_grids = {
    "CatBoostClassifier()": param_grid_cat,
}

# %% [markdown]
# Выполним обучение. Для каждой модели отображается пайп-лайн для контроля.

# %%
# %%time

res = Results()
for name in names.keys():
    print(f"{name}, CV")
    model = FitPredictGo(name, scoring)
    start = time.time()
    result = model.fit_cv(
        preprocessors[name],
        models[name],
        X_train,
        y_train["risk_level"],
        cv_folds,
        True,
    )
    time_cv = round(time.time() - start, 3)
    res.update(result)
    print(f"{name}, Randomized Search")
    start = time.time()
    result = model.fit_search(
        preprocessors[name],
        models[name],
        param_grids[name],
        "Randomized",
        X_train,
        y_train["risk_level"],
        cv_folds,
        True,
    )
    time_rs = round(time.time() - start, 3)
    res.update(result)
    names[name] = model
    print(
        f"--> Done. CV Time = {time_cv} секунд,"
        f" RandomizedSearch Time = {time_rs} секунд"
        f"\n\n"
    )
print("All Done")

sorted_results = res.df.sort_values(
    by="Среднее значение метрики при CV", ascending=False
)
sorted_results
# Out:
# CatBoostClassifier(), CV
# Pipeline(steps=[('nonetype', None),
#                 ('catboostclassifier',
#                  <catboost.core.CatBoostClassifier object at 0x000002627FE7FD40>)])
# Learning rate set to 0.5
# 0:	learn: 0.8316826	total: 191ms	remaining: 18.9s
# 25:	learn: 0.2622475	total: 1.05s	remaining: 2.98s
# 50:	learn: 0.1573383	total: 1.75s	remaining: 1.68s
# 75:	learn: 0.1084888	total: 2.41s	remaining: 763ms
# 99:	learn: 0.0804049	total: 3.08s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8341633	total: 13.8ms	remaining: 1.36s
# 25:	learn: 0.2698206	total: 682ms	remaining: 1.94s
# 50:	learn: 0.1695315	total: 1.34s	remaining: 1.29s
# 75:	learn: 0.1113080	total: 2.06s	remaining: 651ms
# 99:	learn: 0.0894592	total: 2.71s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.7925170	total: 23.3ms	remaining: 2.31s
# 25:	learn: 0.2830024	total: 686ms	remaining: 1.95s
# 50:	learn: 0.1710351	total: 1.38s	remaining: 1.33s
# 75:	learn: 0.1152330	total: 2.08s	remaining: 658ms
# 99:	learn: 0.0861643	total: 2.73s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8173231	total: 22.9ms	remaining: 2.26s
# 25:	learn: 0.2906247	total: 678ms	remaining: 1.93s
# 50:	learn: 0.1590757	total: 1.39s	remaining: 1.33s
# 75:	learn: 0.1029751	total: 2.05s	remaining: 648ms
# 99:	learn: 0.0740601	total: 2.71s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8109459	total: 25.5ms	remaining: 2.53s
# 25:	learn: 0.3065770	total: 695ms	remaining: 1.98s
# 50:	learn: 0.1930639	total: 1.37s	remaining: 1.32s
# 75:	learn: 0.1248733	total: 2.02s	remaining: 639ms
# 99:	learn: 0.0929461	total: 2.69s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8270670	total: 22.9ms	remaining: 2.26s
# 25:	learn: 0.2831945	total: 662ms	remaining: 1.89s
# 50:	learn: 0.1751289	total: 1.32s	remaining: 1.27s
# 75:	learn: 0.1214109	total: 2.04s	remaining: 643ms
# 99:	learn: 0.0915498	total: 2.67s	remaining: 0us
# CatBoostClassifier(), Randomized Search
# Pipeline(steps=[('nonetype', None),
#                 ('catboostclassifier',
#                  <catboost.core.CatBoostClassifier object at 0x000002627FE7FD40>)])
# 0:	learn: 0.8111469	total: 18ms	remaining: 884ms
# 25:	learn: 0.2317664	total: 577ms	remaining: 533ms
# 49:	learn: 0.1206197	total: 1.15s	remaining: 0us
# 0:	learn: 0.8326085	total: 18.8ms	remaining: 919ms
# 25:	learn: 0.2375670	total: 600ms	remaining: 554ms
# 49:	learn: 0.1271916	total: 1.14s	remaining: 0us
# 0:	learn: 0.7815138	total: 18ms	remaining: 880ms
# 25:	learn: 0.2512769	total: 560ms	remaining: 517ms
# 49:	learn: 0.1431708	total: 1.12s	remaining: 0us
# 0:	learn: 0.8020585	total: 17.9ms	remaining: 876ms
# 25:	learn: 0.2606749	total: 572ms	remaining: 528ms
# 49:	learn: 0.1187622	total: 1.13s	remaining: 0us
# 0:	learn: 0.8591833	total: 18.4ms	remaining: 900ms
# 25:	learn: 0.2907171	total: 547ms	remaining: 505ms
# 49:	learn: 0.1545715	total: 1.12s	remaining: 0us
# 0:	learn: 0.9851341	total: 14.1ms	remaining: 691ms
# 25:	learn: 0.4393167	total: 425ms	remaining: 392ms
# 49:	learn: 0.2831930	total: 837ms	remaining: 0us
# 0:	learn: 0.9944811	total: 13.8ms	remaining: 676ms
# 25:	learn: 0.5011808	total: 423ms	remaining: 390ms
# 49:	learn: 0.3298104	total: 854ms	remaining: 0us
# 0:	learn: 0.9483877	total: 14.6ms	remaining: 715ms
# 25:	learn: 0.4525832	total: 444ms	remaining: 409ms
# 49:	learn: 0.3179276	total: 857ms	remaining: 0us
# 0:	learn: 0.9709418	total: 13.4ms	remaining: 656ms
# 25:	learn: 0.4698883	total: 430ms	remaining: 397ms
# 49:	learn: 0.3084132	total: 844ms	remaining: 0us
# 0:	learn: 0.9655620	total: 13.1ms	remaining: 643ms
# 25:	learn: 0.5109691	total: 523ms	remaining: 483ms
# 49:	learn: 0.3497180	total: 933ms	remaining: 0us
# 0:	learn: 0.8428064	total: 18.1ms	remaining: 886ms
# 25:	learn: 0.2973904	total: 553ms	remaining: 510ms
# 49:	learn: 0.1583401	total: 1.06s	remaining: 0us
# 0:	learn: 0.8592772	total: 18.2ms	remaining: 891ms
# 25:	learn: 0.3141302	total: 582ms	remaining: 537ms
# 49:	learn: 0.1776147	total: 1.1s	remaining: 0us
# 0:	learn: 0.8109792	total: 18.7ms	remaining: 918ms
# 25:	learn: 0.3180179	total: 546ms	remaining: 504ms
# 49:	learn: 0.1880377	total: 1.06s	remaining: 0us
# 0:	learn: 0.8327666	total: 17.3ms	remaining: 846ms
# 25:	learn: 0.3075206	total: 580ms	remaining: 535ms
# 49:	learn: 0.1643102	total: 1.12s	remaining: 0us
# 0:	learn: 0.8797039	total: 17ms	remaining: 833ms
# 25:	learn: 0.3233102	total: 569ms	remaining: 526ms
# 49:	learn: 0.1896917	total: 1.11s	remaining: 0us
# 0:	learn: 1.0405767	total: 26.3ms	remaining: 1.29s
# 25:	learn: 0.5704255	total: 774ms	remaining: 714ms
# 49:	learn: 0.4341191	total: 1.47s	remaining: 0us
# 0:	learn: 1.0454702	total: 25.8ms	remaining: 1.26s
# 25:	learn: 0.6171281	total: 691ms	remaining: 637ms
# 49:	learn: 0.4715529	total: 1.45s	remaining: 0us
# 0:	learn: 1.0309585	total: 26.3ms	remaining: 1.29s
# 25:	learn: 0.5739867	total: 735ms	remaining: 678ms
# 49:	learn: 0.4684692	total: 1.4s	remaining: 0us
# 0:	learn: 1.0360581	total: 37.6ms	remaining: 1.84s
# 25:	learn: 0.5876582	total: 756ms	remaining: 697ms
# 49:	learn: 0.4521236	total: 1.48s	remaining: 0us
# 0:	learn: 1.0417623	total: 26.6ms	remaining: 1.3s
# 25:	learn: 0.5832569	total: 750ms	remaining: 692ms
# 49:	learn: 0.4651800	total: 1.44s	remaining: 0us
# 0:	learn: 1.0095723	total: 30.1ms	remaining: 1.47s
# 25:	learn: 0.4411499	total: 762ms	remaining: 703ms
# 49:	learn: 0.2585758	total: 1.6s	remaining: 0us
# 0:	learn: 1.0203667	total: 30ms	remaining: 1.47s
# 25:	learn: 0.4780208	total: 724ms	remaining: 669ms
# 49:	learn: 0.2785896	total: 1.55s	remaining: 0us
# 0:	learn: 1.0085748	total: 31.5ms	remaining: 1.54s
# 25:	learn: 0.4890071	total: 756ms	remaining: 698ms
# 49:	learn: 0.2964921	total: 1.54s	remaining: 0us
# 0:	learn: 1.0168366	total: 30.3ms	remaining: 1.48s
# 25:	learn: 0.4486749	total: 848ms	remaining: 783ms
# 49:	learn: 0.2632802	total: 1.66s	remaining: 0us
# 0:	learn: 1.0131251	total: 30.6ms	remaining: 1.5s
# 25:	learn: 0.4597085	total: 803ms	remaining: 741ms
# 49:	learn: 0.2911407	total: 1.6s	remaining: 0us
# 0:	learn: 0.9900796	total: 32.9ms	remaining: 3.26s
# 25:	learn: 0.4083844	total: 802ms	remaining: 2.28s
# 50:	learn: 0.2317624	total: 1.65s	remaining: 1.58s
# 75:	learn: 0.1552748	total: 2.53s	remaining: 800ms
# 99:	learn: 0.1153281	total: 3.35s	remaining: 0us
# 0:	learn: 1.0097705	total: 32.2ms	remaining: 3.18s
# 25:	learn: 0.4592059	total: 821ms	remaining: 2.34s
# 50:	learn: 0.2569156	total: 1.67s	remaining: 1.6s
# 75:	learn: 0.1738852	total: 2.51s	remaining: 793ms
# 99:	learn: 0.1284809	total: 3.36s	remaining: 0us
# 0:	learn: 1.0023105	total: 30.5ms	remaining: 3.02s
# 25:	learn: 0.4597858	total: 727ms	remaining: 2.07s
# 50:	learn: 0.2592370	total: 1.61s	remaining: 1.55s
# 75:	learn: 0.1742950	total: 2.46s	remaining: 778ms
# 99:	learn: 0.1298252	total: 3.27s	remaining: 0us
# 0:	learn: 1.0038002	total: 31.2ms	remaining: 3.08s
# 25:	learn: 0.4202020	total: 830ms	remaining: 2.36s
# 50:	learn: 0.2264854	total: 1.67s	remaining: 1.61s
# 75:	learn: 0.1479244	total: 2.56s	remaining: 810ms
# 99:	learn: 0.1087092	total: 3.38s	remaining: 0us
# 0:	learn: 0.9976091	total: 31ms	remaining: 3.07s
# 25:	learn: 0.4455096	total: 786ms	remaining: 2.24s
# 50:	learn: 0.2551127	total: 1.67s	remaining: 1.61s
# 75:	learn: 0.1802533	total: 2.51s	remaining: 793ms
# 99:	learn: 0.1359879	total: 3.35s	remaining: 0us
# 0:	learn: 0.9599919	total: 18.3ms	remaining: 898ms
# 25:	learn: 0.3913212	total: 539ms	remaining: 498ms
# 49:	learn: 0.2341361	total: 1.04s	remaining: 0us
# 0:	learn: 0.9718064	total: 17.5ms	remaining: 859ms
# 25:	learn: 0.4441993	total: 542ms	remaining: 500ms
# 49:	learn: 0.3017500	total: 1.09s	remaining: 0us
# 0:	learn: 0.9484020	total: 17.7ms	remaining: 868ms
# 25:	learn: 0.4305490	total: 530ms	remaining: 489ms
# 49:	learn: 0.2580407	total: 1.04s	remaining: 0us
# 0:	learn: 0.9558069	total: 18.3ms	remaining: 896ms
# 25:	learn: 0.4279680	total: 501ms	remaining: 462ms
# 49:	learn: 0.2431530	total: 1.05s	remaining: 0us
# 0:	learn: 0.9860165	total: 19.1ms	remaining: 934ms
# 25:	learn: 0.4507922	total: 493ms	remaining: 455ms
# 49:	learn: 0.2879702	total: 1.01s	remaining: 0us
# 0:	learn: 0.8543330	total: 17.5ms	remaining: 857ms
# 25:	learn: 0.1866792	total: 541ms	remaining: 499ms
# 49:	learn: 0.1011179	total: 1.09s	remaining: 0us
# 0:	learn: 0.8810951	total: 17.3ms	remaining: 849ms
# 25:	learn: 0.2585039	total: 569ms	remaining: 525ms
# 49:	learn: 0.1328975	total: 1.09s	remaining: 0us
# 0:	learn: 0.7735508	total: 18.3ms	remaining: 898ms
# 25:	learn: 0.2254115	total: 568ms	remaining: 525ms
# 49:	learn: 0.1235139	total: 1.12s	remaining: 0us
# 0:	learn: 0.8249295	total: 18.7ms	remaining: 919ms
# 25:	learn: 0.1902692	total: 569ms	remaining: 526ms
# 49:	learn: 0.0972118	total: 1.11s	remaining: 0us
# 0:	learn: 0.8215212	total: 18ms	remaining: 883ms
# 25:	learn: 0.2436073	total: 607ms	remaining: 561ms
# 49:	learn: 0.1363662	total: 1.15s	remaining: 0us
# 0:	learn: 1.0087979	total: 28.1ms	remaining: 2.78s
# 25:	learn: 0.4037365	total: 737ms	remaining: 2.1s
# 50:	learn: 0.1985519	total: 1.56s	remaining: 1.5s
# 75:	learn: 0.1116325	total: 2.35s	remaining: 741ms
# 99:	learn: 0.0766657	total: 3.12s	remaining: 0us
# 0:	learn: 1.0173766	total: 27.1ms	remaining: 2.68s
# 25:	learn: 0.4673162	total: 748ms	remaining: 2.13s
# 50:	learn: 0.2432499	total: 1.59s	remaining: 1.52s
# 75:	learn: 0.1480694	total: 2.38s	remaining: 753ms
# 99:	learn: 0.0999679	total: 3.2s	remaining: 0us
# 0:	learn: 0.9833335	total: 25.4ms	remaining: 2.52s
# 25:	learn: 0.4061362	total: 746ms	remaining: 2.12s
# 50:	learn: 0.2168395	total: 1.56s	remaining: 1.5s
# 75:	learn: 0.1259664	total: 2.36s	remaining: 745ms
# 99:	learn: 0.0859434	total: 3.13s	remaining: 0us
# 0:	learn: 1.0040778	total: 27.3ms	remaining: 2.71s
# 25:	learn: 0.4264045	total: 770ms	remaining: 2.19s
# 50:	learn: 0.2176005	total: 1.57s	remaining: 1.5s
# 75:	learn: 0.1134927	total: 2.4s	remaining: 757ms
# 99:	learn: 0.0744117	total: 3.18s	remaining: 0us
# 0:	learn: 0.9977788	total: 28.4ms	remaining: 2.81s
# 25:	learn: 0.4396044	total: 752ms	remaining: 2.14s
# 50:	learn: 0.2477131	total: 1.5s	remaining: 1.44s
# 75:	learn: 0.1383063	total: 2.34s	remaining: 740ms
# 99:	learn: 0.0899478	total: 3.1s	remaining: 0us
# 0:	learn: 0.9009058	total: 17.5ms	remaining: 857ms
# 25:	learn: 0.2073432	total: 575ms	remaining: 531ms
# 49:	learn: 0.0921731	total: 1.11s	remaining: 0us
# 0:	learn: 0.9165426	total: 17.9ms	remaining: 875ms
# 25:	learn: 0.2627526	total: 556ms	remaining: 513ms
# 49:	learn: 0.1264672	total: 1.11s	remaining: 0us
# 0:	learn: 0.8375971	total: 18.4ms	remaining: 900ms
# 25:	learn: 0.2664555	total: 598ms	remaining: 552ms
# 49:	learn: 0.1285310	total: 1.13s	remaining: 0us
# 0:	learn: 0.8785057	total: 18.8ms	remaining: 921ms
# 25:	learn: 0.2153791	total: 551ms	remaining: 509ms
# 49:	learn: 0.0810582	total: 1.11s	remaining: 0us
# 0:	learn: 0.8704019	total: 17.1ms	remaining: 838ms
# 25:	learn: 0.2747146	total: 600ms	remaining: 554ms
# 49:	learn: 0.1285422	total: 1.12s	remaining: 0us
# 0:	learn: 1.0327860	total: 26.3ms	remaining: 1.29s
# 25:	learn: 0.5777621	total: 767ms	remaining: 708ms
# 49:	learn: 0.4676479	total: 1.5s	remaining: 0us
# --> Done. CV Time = 16.937 секунд, RandomizedSearch Time = 83.26 секунд
#
#
# All Done
# CPU times: total: 2min 50s
# Wall time: 1min 40s
#                         Наименование модели  Время обучения, сек.  \
# 0                      CatBoostClassifier()                 2.838
# 1  Randomized enhanced CatBoostClassifier()                 1.488
#
#    Время предсказания, сек.  Среднее значение метрики при CV  \
# 0                     0.004                            0.756
# 1                     0.004                            0.755
#
#    СКО метрики при CV
# 0               0.041
# 1               0.015

# %%
best_model_1 = names["CatBoostClassifier()"].get_best_estimator("Randomized")

# %%
print("Лучшая модель и её параметры:\n\n", best_model_1.steps[1][1].get_params())
# Out:
# Лучшая модель и её параметры:
#
#  {'random_seed': 1206, 'verbose': 25, 'n_estimators': 50, 'cat_features': ['age_group', 'pressure_group'], 'learning_rate': 0.1, 'l2_leaf_reg': 2, 'depth': 7, 'auto_class_weights': 'SqrtBalanced'}

# %% [markdown]
# ## Сохранение модели и данных для дальнейшей работы

# %% [markdown]
# Модель, показавшая лучший результат, чем бейзлайн модель после подбора гиперпараметров может быть сохранена, как финальная модель текущего исследования.

# %%
joblib.dump(best_model_1, "../../models/exp3_model_756.joblib")
# Out:
# ['../../models/exp3_model_756.joblib']

# %% [markdown]
# Данные, на которых обучена лучшая модель текущего исследования не изменились. Сохранять их не будем.
